# %%
import pandas as pd
import pickle
from tensorflow.keras.models import load_model

# %%
# Loading the dataset
X_test = pd.read_csv('X_test')
X_test_copy = X_test.copy()
Y_test = pd.read_csv('Y_test')

# %%
# Loading the necessary encoders, scalars, model
with open('label_encoder_sex.pkl','rb') as file:
    label_encoder_sex = pickle.load(file)

with open('label_encoder_smoke.pkl','rb') as file:
    label_encoder_smoke = pickle.load(file)

with open('onehot_region.pkl','rb') as file:
    onehot_region = pickle.load(file)    

with open('scalar.pkl','rb') as file:
    scalar = pickle.load(file)    

model = load_model('model.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# Label Encoding
X_test['sex'] = label_encoder_sex.transform(X_test['sex'])
X_test['smoker'] = label_encoder_smoke.transform(X_test['smoker'])

# %%
# One Hot Encoding
X_test_region = onehot_region.transform(X_test[['region']])
col_names = onehot_region.get_feature_names_out()
encoded_df_test = pd.DataFrame(X_test_region,columns = col_names )
X_test = X_test.drop('region',axis = 1)
X_test = pd.concat([X_test, encoded_df_test], axis = 1)

# %%
# Scaling
X_test = scalar.transform(X_test)

# %%
# Prediction
predict = model.predict(X_test)
predict
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# array([[ 9271.255  ],
#        [ 6487.5757 ],
#        [36693.23   ],
#        [11384.964  ],
#        [29809.623  ],
#        [ 9088.503  ],
#        [ 2643.5264 ],
#        [16835.514  ],
#        [ 4157.567  ],
#        [12337.605  ],
#        [22562.223  ],
#        [ 9048.215  ],
#        [ 4072.1577 ],
#        [50425.105  ],
#        [52085.12   ],
#        [46204.316  ],
#        [12167.072  ],
#        [41967.14   ],
#        [ 9711.266  ],
#        [28774.979  ],
#        [ 4218.8916 ],
#        [ 8531.945  ],
#        [ 1113.4191 ],
#        [ 8844.207  ],
#        [12858.529  ],
#        [12218.731  ],
#        [14218.352  ],
#        [ 6532.916  ],
#        [ 9897.148  ],
#        [ 3047.3982 ],
#        [ 6936.501  ],
#        [12988.275  ],
#        [ 3156.124  ],
#        [ 6517.462  ],
#        [ 2345.5938 ],
#        [ 9424.757  ],
#        [ 2526.1082 ],
#        [ 8013.8438 ],
#        [28831.271  ],
#        [37960.42   ],
#        [ 2238.0247 ],
#        [ 2116.7244 ],
#        [12954.591  ],
#        [12924.011  ],
#        [ 5887.07   ],
#        [14816.002  ],
#        [ 5378.544  ],
#        [ 3135.202  ],
#        [41375.395  ],
#        [ 5547.0596 ],
#        [15739.408  ],
#        [ 2949.739  ],
#        [11715.546  ],
#        [ 3120.8145 ],
#        [12818.025  ],
#        [11439.365  ],
#        [ 4348.891  ],
#        [35130.074  ],
#        [13561.258  ],
#        [12044.123  ],
#        [15737.101  ],
#        [ 6674.6226 ],
#        [16144.58   ],
#        [ 9613.667  ],
#        [11070.378  ],
#        [ 4980.538  ],
#        [21698.266  ],
#        [13569.37   ],
#        [ 3852.8042 ],
#        [ 4914.676  ],
#        [ 8695.501  ],
#        [11244.137  ],
#        [ 9756.316  ],
#        [ 7706.7026 ],
#        [ 9166.184  ],
#        [ 5986.887  ],
#        [ 7918.388  ],
#        [12611.874  ],
#        [ 3875.189  ],
#        [ 9336.931  ],
#        [ 3207.7163 ],
#        [35094.316  ],
#        [ 5093.612  ],
#        [38592.777  ],
#        [56587.47   ],
#        [37825.367  ],
#        [ 5792.014  ],
#        [11865.185  ],
#        [ 9962.155  ],
#        [13286.009  ],
#        [18668.607  ],
#        [31178.045  ],
#        [30204.18   ],
#        [ 6480.078  ],
#        [37760.152  ],
#        [ 7749.927  ],
#        [28810.959  ],
#        [ 2564.6157 ],
#        [21135.13   ],
#        [ 7543.505  ],
#        [ 5695.59   ],
#        [ 2260.044  ],
#        [ 8569.629  ],
#        [14317.867  ],
#        [13134.387  ],
#        [ 2825.204  ],
#        [ 9337.119  ],
#        [25458.373  ],
#        [ 2079.8364 ],
#        [26564.752  ],
#        [  897.09534],
#        [ 9262.597  ],
#        [14418.102  ],
#        [34751.082  ],
#        [10677.848  ],
#        [ 1465.6854 ],
#        [13094.055  ],
#        [29165.514  ],
#        [ 6809.288  ],
#        [ 3199.6196 ],
#        [ 9371.222  ],
#        [ 9012.408  ],
#        [14785.175  ],
#        [ 3845.897  ],
#        [ 5225.1465 ],
#        [ 9358.246  ],
#        [ 8441.415  ],
#        [10054.505  ],
#        [14017.126  ],
#        [ 5468.4116 ],
#        [ 4808.5425 ],
#        [ 6901.1484 ],
#        [ 5958.0063 ],
#        [11595.638  ],
#        [ 7228.7993 ],
#        [14367.646  ],
#        [ 6937.604  ],
#        [33776.703  ],
#        [44839.336  ],
#        [33767.676  ],
#        [ 6314.0474 ],
#        [11751.368  ],
#        [ 4306.0757 ],
#        [13670.108  ],
#        [ 4145.2036 ],
#        [30538.215  ],
#        [ 6550.194  ],
#        [ 5197.197  ],
#        [13792.344  ],
#        [ 5411.2295 ],
#        [46103.836  ],
#        [ 3826.9956 ],
#        [ 4269.2266 ],
#        [35778.77   ],
#        [10557.106  ],
#        [ 6923.045  ],
#        [14410.675  ],
#        [10000.134  ],
#        [30129.436  ],
#        [36739.06   ],
#        [15023.285  ],
#        [ 3242.4602 ],
#        [17192.518  ],
#        [ 3333.3206 ],
#        [ 2565.1313 ],
#        [ 8499.386  ],
#        [50216.664  ],
#        [39326.645  ],
#        [35831.598  ],
#        [ 3742.437  ],
#        [11451.129  ],
#        [ 7042.881  ],
#        [10309.08   ],
#        [ 5524.994  ],
#        [ 2955.149  ],
#        [28809.121  ],
#        [25176.34   ],
#        [16403.643  ],
#        [13695.71   ],
#        [12915.886  ],
#        [36511.78   ],
#        [ 4059.0852 ],
#        [11144.562  ],
#        [ 5833.108  ],
#        [ 6115.951  ],
#        [ 5067.1006 ],
#        [ 5944.746  ],
#        [ 4927.238  ],
#        [12616.844  ],
#        [11616.901  ],
#        [ 3776.3823 ],
#        [ 5781.4697 ],
#        [ 4754.956  ],
#        [38109.465  ],
#        [15267.539  ],
#        [10928.005  ],
#        [ 3031.9624 ],
#        [12760.4795 ],
#        [ 5048.102  ],
#        [11279.629  ],
#        [ 3734.9844 ],
#        [33061.496  ],
#        [ 8131.94   ],
#        [ 2558.3308 ],
#        [22629.666  ],
#        [21384.97   ],
#        [10095.091  ],
#        [ 4250.238  ],
#        [10513.582  ],
#        [ 3417.803  ],
#        [16679.248  ],
#        [14609.353  ],
#        [19908.975  ],
#        [24429.348  ],
#        [ 8607.559  ],
#        [ 6953.49   ],
#        [ 5391.1196 ],
#        [15947.889  ],
#        [15319.091  ],
#        [ 5891.473  ],
#        [ 5357.306  ],
#        [11080.017  ],
#        [11936.4    ],
#        [43896.375  ],
#        [ 2032.5366 ],
#        [30847.68   ],
#        [ 2132.265  ],
#        [ 1697.566  ],
#        [11375.75   ],
#        [12959.7705 ],
#        [ 3320.2258 ],
#        [11096.894  ],
#        [ 4274.7466 ],
#        [31493.924  ],
#        [11340.407  ],
#        [10486.946  ],
#        [ 4321.789  ],
#        [ 7184.5244 ],
#        [45353.043  ],
#        [ 3427.161  ],
#        [13094.792  ],
#        [36661.047  ],
#        [ 5597.241  ],
#        [ 3114.064  ],
#        [ 2252.63   ],
#        [ 2783.3337 ],
#        [ 4073.523  ],
#        [ 4131.7466 ],
#        [18293.064  ],
#        [ 3912.8962 ],
#        [ 2510.5938 ],
#        [ 8258.122  ],
#        [ 4402.689  ],
#        [12062.317  ],
#        [ 4184.068  ],
#        [ 2700.4607 ],
#        [14663.997  ],
#        [ 3545.4568 ],
#        [ 8544.774  ],
#        [ 9375.674  ],
#        [ 9716.283  ],
#        [14173.272  ],
#        [27379.922  ],
#        [45638.19   ],
#        [13249.085  ],
#        [ 7069.357  ],
#        [58087.773  ],
#        [10647.868  ]], dtype=float32)

# %%
predictions_df = pd.DataFrame(predict, columns=['Predicted_Y'])
result_df = pd.concat([X_test_copy.reset_index(drop=True), Y_test.reset_index(drop=True), predictions_df], axis=1)
result_df.rename(columns={'charges': 'Original Y'}, inplace=True)

# %%
result_df
# Out:
#      age     sex     bmi  children smoker     region   Original Y  \
# 0     45  female  25.175         2     no  northeast   9095.06825
# 1     36  female  30.020         0     no  northwest   5272.17580
# 2     64  female  26.885         0    yes  northwest  29330.98315
# 3     46    male  25.745         3     no  northwest   9301.89355
# 4     19    male  31.920         0    yes  northwest  33750.29180
# ..   ...     ...     ...       ...    ...        ...          ...
# 263   63    male  35.090         0    yes  southeast  47055.53210
# 264   58  female  27.170         0     no  northwest  12222.89830
# 265   38    male  28.025         1     no  northeast   6067.12675
# 266   54  female  47.410         0    yes  southeast  63770.42801
# 267   51  female  34.200         1     no  southwest   9872.70100
#
#       Predicted_Y
# 0     9271.254883
# 1     6487.575684
# 2    36693.230469
# 3    11384.963867
# 4    29809.623047
# ..            ...
# 263  45638.191406
# 264  13249.084961
# 265   7069.356934
# 266  58087.773438
# 267  10647.868164
#
# [268 rows x 8 columns]
